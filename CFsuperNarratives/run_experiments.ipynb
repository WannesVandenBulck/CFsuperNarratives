# %%
# !python scripts/experiments/make_cf_tables.py
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.92      0.89      7414
#            1       0.68      0.54      0.60      2355
#
#     accuracy                           0.83      9769
#    macro avg       0.77      0.73      0.75      9769
# weighted avg       0.82      0.83      0.82      9769
#
# Accuracy: 0.83
# AUC: 0.86
# Generating CF table for instance 0...
# Saved data\cf_tables\instance_0.csv
# Generating CF table for instance 1...
# Saved data\cf_tables\instance_1.csv
# Generating CF table for instance 2...
# Saved data\cf_tables\instance_2.csv
# Generating CF table for instance 3...
# Saved data\cf_tables\instance_3.csv
# Generating CF table for instance 4...
# Saved data\cf_tables\instance_4.csv
# ...

# %%
# !python scripts/experiments/run_cf_experiments.py
# Out:
# >>> make_cf_tables.py is running c:\Users\wavandenbulck\Desktop\CFsuperNarratives\scripts\experiments\run_cf_experiments.py
# Traceback (most recent call last):
#   File "c:\Users\wavandenbulck\Desktop\CFsuperNarratives\scripts\experiments\run_cf_experiments.py", line 6, in <module>
#     from cfsupernarratives_metrics.llm_tools.prompts import build_cf_prompt
# ModuleNotFoundError: No module named 'cfsupernarratives_metrics'
